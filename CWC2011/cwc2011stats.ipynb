# %% [markdown]
# ### <center>1. Importing the dataset</center>

# %%
# Importing the dataset
import pandas as pd
df = pd.read_csv('icc_world_cup_2011.csv')
df
# Out:
#            team1         team2        winner     margin  \
# 0     Bangladesh         India         India    87 runs
# 1    New Zealand         Kenya   New Zealand    10 wkts
# 2      Sri Lanka        Canada     Sri Lanka   210 runs
# 3      Australia      Zimbabwe     Australia    91 runs
# 4        England   Netherlands       England     6 wkts
# 5       Pakistan         Kenya      Pakistan   205 runs
# 6   South Africa   West Indies  South Africa     7 wkts
# 7      Australia   New Zealand     Australia     7 wkts
# 8     Bangladesh       Ireland    Bangladesh    27 runs
# 9      Sri Lanka      Pakistan      Pakistan    11 runs
# 10         India       England            NR       Tied
# 11      Zimbabwe        Canada      Zimbabwe   175 runs
# 12   West Indies   Netherlands   West Indies   215 runs
# 13     Sri Lanka         Kenya     Sri Lanka     9 wkts
# 14       England       Ireland       Ireland     3 wkts
# 15  South Africa   Netherlands  South Africa   231 runs
# 16      Pakistan        Canada      Pakistan    46 runs
# 17   New Zealand      Zimbabwe   New Zealand    10 wkts
# 18    Bangladesh   West Indies   West Indies     9 wkts
# 19     Sri Lanka     Australia            NR  Abandoned
# 20       England  South Africa       England     6 runs
# 21         India       Ireland         India     5 wkts
# 22         Kenya        Canada        Canada     5 wkts
# 23      Pakistan   New Zealand   New Zealand   110 runs
# 24         India   Netherlands         India     5 wkts
# 25     Sri Lanka      Zimbabwe     Sri Lanka   139 runs
# 26   West Indies       Ireland   West Indies    44 runs
# 27    Bangladesh       England    Bangladesh     2 wkts
# 28         India  South Africa  South Africa     3 wkts
# 29   New Zealand        Canada   New Zealand    97 runs
# 30     Australia         Kenya     Australia    60 runs
# 31    Bangladesh   Netherlands    Bangladesh     6 wkts
# 32      Pakistan      Zimbabwe      Pakistan     7 wkts
# 33  South Africa       Ireland  South Africa   131 runs
# 34     Australia        Canada     Australia     7 wkts
# 35       England   West Indies       England    18 runs
# 36       Ireland   Netherlands       Ireland     6 wkts
# 37     Sri Lanka   New Zealand     Sri Lanka   112 runs
# 38    Bangladesh  South Africa  South Africa   206 runs
# 39     Australia      Pakistan      Pakistan     4 wkts
# 40      Zimbabwe         Kenya      Zimbabwe   161 runs
# 41         India   West Indies         India    80 runs
# 42      Pakistan   West Indies      Pakistan    10 wkts
# 43         India     Australia         India     5 wkts
# 44   New Zealand  South Africa   New Zealand    49 runs
# 45     Sri Lanka       England     Sri Lanka    10 wkts
# 46     Sri Lanka   New Zealand     Sri Lanka     5 wkts
# 47         India      Pakistan         India    29 runs
# 48         India     Sri Lanka         India     6 wkts
#
#                                           ground        venue
# 0                  Shere Bangla National Stadium        Dhaka
# 1                         MA Chidambaram Stadium      Chennai
# 2        Mahinda Rajapaksa International Stadium   Hambantota
# 3                          Narendra Modi Stadium    Ahmedabad
# 4           Vidarbha Cricket Association Stadium       Nagpur
# 5        Mahinda Rajapaksa International Stadium   Hambantota
# 6                           Arun Jaitley Stadium        Delhi
# 7           Vidarbha Cricket Association Stadium       Nagpur
# 8                  Shere Bangla National Stadium        Dhaka
# 9                            R.Premadasa Stadium      Colombo
# 10                         M.Chinnaswamy Stadium    Bengaluru
# 11          Vidarbha Cricket Association Stadium       Nagpur
# 12                          Arun Jaitley Stadium        Delhi
# 13                           R.Premadasa Stadium      Colombo
# 14                         M.Chinnaswamy Stadium    Bengaluru
# 15  Punjab Cricket Association IS Bindra Stadium       Mohali
# 16                           R.Premadasa Stadium      Colombo
# 17                         Narendra Modi Stadium    Ahmedabad
# 18                 Shere Bangla National Stadium        Dhaka
# 19                           R.Premadasa Stadium      Colombo
# 20                        MA Chidambaram Stadium      Chennai
# 21                         M.Chinnaswamy Stadium    Bengaluru
# 22                          Arun Jaitley Stadium        Delhi
# 23       Pallekele International Cricket Stadium    Pallekele
# 24                          Arun Jaitley Stadium        Delhi
# 25       Pallekele International Cricket Stadium    Pallekele
# 26  Punjab Cricket Association IS Bindra Stadium       Mohali
# 27                 Zahur Ahmed Chowdhury Stadium   Chattogram
# 28          Vidarbha Cricket Association Stadium       Nagpur
# 29                              Wankhede Stadium       Mumbai
# 30                         M.Chinnaswamy Stadium    Bengaluru
# 31                 Zahur Ahmed Chowdhury Stadium   Chattogram
# 32       Pallekele International Cricket Stadium    Pallekele
# 33                                  Eden Gardens      Kolkata
# 34                         M.Chinnaswamy Stadium    Bengaluru
# 35                        MA Chidambaram Stadium      Chennai
# 36                                  Eden Gardens      Kolkata
# 37                              Wankhede Stadium       Mumbai
# 38                 Shere Bangla National Stadium        Dhaka
# 39                           R.Premadasa Stadium      Colombo
# 40                                  Eden Gardens      Kolkata
# 41                        MA Chidambaram Stadium      Chennai
# 42                 Shere Bangla National Stadium        Dhaka
# 43                Narendra Modi Stadium A Ground    Ahmedabad
# 44                 Shere Bangla National Stadium        Dhaka
# 45                           R.Premadasa Stadium      Colombo
# 46                           R.Premadasa Stadium      Colombo
# 47  Punjab Cricket Association IS Bindra Stadium       Mohali
# 48                              Wankhede Stadium       Mumbai

# %%
# Checking the presence of null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   team1   49 non-null     object
#  1   team2   49 non-null     object
#  2   winner  49 non-null     object
#  3   margin  49 non-null     object
#  4   ground  49 non-null     object
#  5   venue   49 non-null     object
# dtypes: object(6)
# memory usage: 2.4+ KB

# %%
# Check duplicacy of the values
df.count()
# Out:
# team1     49
# team2     49
# winner    49
# margin    49
# ground    49
# venue     49
# dtype: int64

# %% [markdown]
# ### <center>2. Calculation & Aggregation of Data</center>

# %%
# Calculating the total matches played by each team
team1_total = df.groupby('team1').size()
team2_total = df.groupby('team2').size()
total_matches_played = pd.concat([team1_total, team2_total]).groupby(level=0).sum()
total_matches_played
# Out:
# Australia       7
# Bangladesh      6
# Canada          6
# England         7
# India           9
# Ireland         6
# Kenya           6
# Netherlands     6
# New Zealand     8
# Pakistan        8
# South Africa    7
# Sri Lanka       9
# West Indies     7
# Zimbabwe        6
# dtype: int64

# %%
# Calculate the 'wins' for each team
team1_wins = df[df['team1'] == df['winner']].groupby('team1').size()
team2_wins = df[df['team2'] == df['winner']].groupby('team2').size()
total_wins = pd.concat([team1_wins, team2_wins]).groupby(level=0).sum()
total_wins
# Out:
# Australia       4
# Bangladesh      3
# Canada          1
# England         3
# India           7
# Ireland         2
# New Zealand     5
# Pakistan        6
# South Africa    5
# Sri Lanka       6
# West Indies     3
# Zimbabwe        2
# dtype: int64

# %%
# Calculate the 'nr' (No Result) for each team
team1_nr = df[df['winner'] == 'NR'].groupby('team1').size()
team2_nr = df[df['winner'] == 'NR'].groupby('team2').size()
total_nr = pd.concat([team1_nr, team2_nr]).groupby(level=0).sum()
total_nr
# Out:
# Australia    1
# England      1
# India        1
# Sri Lanka    1
# dtype: int64

# %%
# Merge the calculation series into a single Pandas dataframe
all_matches = pd.concat([total_matches_played, total_wins, total_nr], axis=1)
all_matches.columns = ['total_matches', 'total_wins', 'total_nr']
all_matches = all_matches.fillna(0)
all_matches = all_matches.astype(int)
all_matches
# Out:
#               total_matches  total_wins  total_nr
# Australia                 7           4         1
# Bangladesh                6           3         0
# Canada                    6           1         0
# England                   7           3         1
# India                     9           7         1
# Ireland                   6           2         0
# Kenya                     6           0         0
# Netherlands               6           0         0
# New Zealand               8           5         0
# Pakistan                  8           6         0
# South Africa              7           5         0
# Sri Lanka                 9           6         1
# West Indies               7           3         0
# Zimbabwe                  6           2         0

# %%
# Calculating the losses and the points.
all_matches['loss'] = all_matches['total_matches'] - all_matches['total_wins'] - all_matches['total_nr']
all_matches['pts'] = (all_matches['total_wins'] * 2) + all_matches['total_nr']
all_matches
# Out:
#               total_matches  total_wins  total_nr  loss  pts
# Australia                 7           4         1     2    9
# Bangladesh                6           3         0     3    6
# Canada                    6           1         0     5    2
# England                   7           3         1     3    7
# India                     9           7         1     1   15
# Ireland                   6           2         0     4    4
# Kenya                     6           0         0     6    0
# Netherlands               6           0         0     6    0
# New Zealand               8           5         0     3   10
# Pakistan                  8           6         0     2   12
# South Africa              7           5         0     2   10
# Sri Lanka                 9           6         1     2   13
# West Indies               7           3         0     4    6
# Zimbabwe                  6           2         0     4    4

# %%
# Sort the DataFrame by 'pts' in descending order
all_matches = all_matches.sort_values(by='pts', ascending=False)
all_matches
# Out:
#               total_matches  total_wins  total_nr  loss  pts
# India                     9           7         1     1   15
# Sri Lanka                 9           6         1     2   13
# Pakistan                  8           6         0     2   12
# New Zealand               8           5         0     3   10
# South Africa              7           5         0     2   10
# Australia                 7           4         1     2    9
# England                   7           3         1     3    7
# Bangladesh                6           3         0     3    6
# West Indies               7           3         0     4    6
# Ireland                   6           2         0     4    4
# Zimbabwe                  6           2         0     4    4
# Canada                    6           1         0     5    2
# Kenya                     6           0         0     6    0
# Netherlands               6           0         0     6    0
