# 13              119 runs               Hagley Oval   Christchurch
# 14  73 runs (D/L method)               Manuka Oval       Canberra
# 15                2 wkts                 The Gabba       Brisbane
# 16                 1 wkt           University Oval        Dunedin
# 17               92 runs  Melbourne Cricket Ground      Melbourne
# 18              257 runs     Sydney Cricket Ground         Sydney
# 19                 1 wkt                 Eden Park       Auckland
# 20                9 wkts           W.A.C.A. Ground          Perth
# 21                9 wkts               Sky Stadium     Wellington
# 22               20 runs                 The Gabba       Brisbane
# 23              201 runs               Manuka Oval       Canberra
# 24              129 runs               McLean Park         Napier
# 25              275 runs           W.A.C.A. Ground          Perth
# 26                6 wkts               Saxton Oval         Nelson
# 27                4 wkts           W.A.C.A. Ground          Perth
# 28  29 runs (D/L method)                 Eden Park       Auckland
# 29                5 runs            Bellerive Oval         Hobart
# 30                6 wkts               McLean Park         Napier
# 31               64 runs     Sydney Cricket Ground         Sydney
# 32               15 runs             Adelaide Oval       Adelaide
# 33                8 wkts               Seddon Park       Hamilton
# 34              148 runs            Bellerive Oval         Hobart
# 35              146 runs               Sky Stadium     Wellington
# 36                3 wkts               Seddon Park       Hamilton
# 37   9 wkts (D/L method)     Sydney Cricket Ground         Sydney
# 38                6 wkts                 Eden Park       Auckland
# 39                7 wkts            Bellerive Oval         Hobart
# 40                6 wkts               McLean Park         Napier
# 41                7 wkts             Adelaide Oval       Adelaide
# 42                9 wkts     Sydney Cricket Ground         Sydney
# 43              109 runs  Melbourne Cricket Ground      Melbourne
# 44                6 wkts             Adelaide Oval       Adelaide
# 45              143 runs               Sky Stadium     Wellington
# 46   4 wkts (D/L method)                 Eden Park       Auckland
# 47               95 runs     Sydney Cricket Ground         Sydney
# 48                7 wkts  Melbourne Cricket Ground      Melbourne

# %%
# Checking the presence of null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   team1   49 non-null     object
#  1   team2   49 non-null     object
#  2   winner  49 non-null     object
#  3   margin  49 non-null     object
#  4   ground  49 non-null     object
#  5   venue   49 non-null     object
# dtypes: object(6)
# memory usage: 2.4+ KB

# %%
# Check duplicacy of the values
df.count()
# Out:
# team1     49
# team2     49
# winner    49
# margin    49
# ground    49
# venue     49
# dtype: int64

# %% [markdown]
# ### <center>2. Calculation & Aggregation of Data</center>

# %%
# Calculating the total matches played by each team
team1_total = df.groupby('team1').size()
team2_total = df.groupby('team2').size()
total_matches_played = pd.concat([team1_total, team2_total]).groupby(level=0).sum()
total_matches_played
# Out:
# Afghanistan             6
# Australia               9
# Bangladesh              7
# England                 6
# India                   8
# Ireland                 6
# New Zealand             9
# Pakistan                7
# Scotland                6
# South Africa            8
# Sri Lanka               7
# United Arab Emirates    6
# West Indies             7
# Zimbabwe                6
# dtype: int64

# %%
# Calculate the 'wins' for each team
team1_wins = df[df['team1'] == df['winner']].groupby('team1').size()
team2_wins = df[df['team2'] == df['winner']].groupby('team2').size()
total_wins = pd.concat([team1_wins, team2_wins]).groupby(level=0).sum()
total_wins
# Out:
# Afghanistan     1
# Australia       7
# Bangladesh      3
# England         1
# India           7
# Ireland         3
# New Zealand     7
# Pakistan        4
# South Africa    5
# Sri Lanka       4
# West Indies     3
# Zimbabwe        1
# dtype: int64

# %%
# Calculate the 'nr' (No Result) for each team
team1_nr = df[df['winner'] == 'NR'].groupby('team1').size()
team2_nr = df[df['winner'] == 'NR'].groupby('team2').size()
total_nr = pd.concat([team1_nr, team2_nr]).groupby(level=0).sum()
total_nr
# Out:
# Australia     1
# Bangladesh    1
# dtype: int64

# %%
# Merge the calculation series into a single Pandas dataframe
all_matches = pd.concat([total_matches_played, total_wins, total_nr], axis=1)
all_matches.columns = ['total_matches', 'total_wins', 'total_nr']
all_matches = all_matches.fillna(0)
all_matches = all_matches.astype(int)
all_matches
# Out:
#                       total_matches  total_wins  total_nr
# Afghanistan                       6           1         0
# Australia                         9           7         1
# Bangladesh                        7           3         1
# England                           6           1         0
# India                             8           7         0
# Ireland                           6           3         0
# New Zealand                       9           7         0
# Pakistan                          7           4         0
# Scotland                          6           0         0
# South Africa                      8           5         0
# Sri Lanka                         7           4         0
# United Arab Emirates              6           0         0
# West Indies                       7           3         0
# Zimbabwe                          6           1         0

# %%
# Calculating the losses and the points.
all_matches['loss'] = all_matches['total_matches'] - all_matches['total_wins'] - all_matches['total_nr']
all_matches['pts'] = (all_matches['total_wins'] * 2) + all_matches['total_nr']
all_matches
# Out:
#                       total_matches  total_wins  total_nr  loss  pts
# Afghanistan                       6           1         0     5    2
# Australia                         9           7         1     1   15
# Bangladesh                        7           3         1     3    7
# England                           6           1         0     5    2
# India                             8           7         0     1   14
# Ireland                           6           3         0     3    6
# New Zealand                       9           7         0     2   14
# Pakistan                          7           4         0     3    8
# Scotland                          6           0         0     6    0
# South Africa                      8           5         0     3   10
# Sri Lanka                         7           4         0     3    8
# United Arab Emirates              6           0         0     6    0
# West Indies                       7           3         0     4    6
# Zimbabwe                          6           1         0     5    2

# %%
# Sort the DataFrame by 'pts' in descending order
all_matches = all_matches.sort_values(by=['total_matches', 'pts'], ascending=False)
all_matches
# Out:
#                       total_matches  total_wins  total_nr  loss  pts
# Australia                         9           7         1     1   15
# New Zealand                       9           7         0     2   14
# India                             8           7         0     1   14
# South Africa                      8           5         0     3   10
# Pakistan                          7           4         0     3    8
# Sri Lanka                         7           4         0     3    8
# Bangladesh                        7           3         1     3    7
# West Indies                       7           3         0     4    6
# Ireland                           6           3         0     3    6
# Afghanistan                       6           1         0     5    2
# England                           6           1         0     5    2
# Zimbabwe                          6           1         0     5    2
# Scotland                          6           0         0     6    0
# United Arab Emirates              6           0         0     6    0
